# %%
# Titanic Dataset

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# %%
df = pd.read_csv("train.csv")

# %% [markdown]
# # 1.Assessing Data

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.shape
# Out:
# (891, 12)

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# # 2. Data Cleaning

# %%
df.drop(columns=['PassengerId','Name','Ticket','Cabin'],inplace=True)

# %%
df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Fare          0
# Embarked      2
# dtype: int64

# %% [markdown]
# Step 2: Handle missing values using mean/median/imputation

# %%
# calculated the median value
median_age = int(df['Age'].median())
median_age
# Out:
# 28

# %%
# filled null values
df['Age'] = df['Age'].fillna(median_age)

# %%
# converted from float to int 
df['Age'] = df['Age'].round().astype(int)

# %%
df['Age'].isnull().sum()
# Out:
# 0

# %%
df['Age']
# Out:
# 0      22
# 1      38
# 2      26
# 3      35
# 4      35
#        ..
# 886    27
# 887    19
# 888    28
# 889    26
# 890    32
# Name: Age, Length: 891, dtype: int32

# %%
df['Embarked']=df['Embarked'].bfill()

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Embarked    0
# dtype: int64

# %%
# Adding column of Family
df['Family'] = df['SibSp']+df['Parch']
df.sample(15)
# Out:
#      Survived  Pclass     Sex  Age  SibSp  Parch     Fare Embarked  Family
# 11          1       1  female   58      0      0  26.5500        S       0
# 596         1       2  female   28      0      0  33.0000        S       0
# 526         1       2  female   50      0      0  10.5000        S       0
# 46          0       3    male   28      1      0  15.5000        Q       1
# 465         0       3    male   38      0      0   7.0500        S       0
# 623         0       3    male   21      0      0   7.8542        S       0
# 458         1       2  female   50      0      0  10.5000        S       0
# 194         1       1  female   44      0      0  27.7208        C       0
# 633         0       1    male   28      0      0   0.0000        S       0
# 750         1       2  female    4      1      1  23.0000        S       2
# 289         1       3  female   22      0      0   7.7500        Q       0
# ...

# %% [markdown]
# # 3. Visualization

# %%
# Histogram
cols = ['Survived','Pclass','Age','Fare','Family']
df_num = df[cols]
df_num.hist(figsize=(10, 8))
plt.suptitle('Histograms of Numeric Features')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
plt.figure(figsize=(15, 8))
for i, col in enumerate(df_num, 1):
    plt.subplot(3, 2, i)
    sns.boxplot(y=df[col])
    plt.title(f'Boxplot of {col}')
plt.tight_layout()
plt.show()

# %%
def remove_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    return data[(data[column] >= lower) & (data[column] <= upper)]


for col in df_num:
    df = remove_outliers_iqr(df, col)


print("Shape after outlier removal:", df.shape)
# Out:
# Shape after outlier removal: (660, 9)

# %%
print("After Removing Outliers")
numerical_cols = ['Age', 'Fare']
plt.figure(figsize=(15, 8))
for i, col in enumerate(df_num, 1):
    plt.subplot(3, 2, i)
    sns.boxplot(y=df[col])
    plt.title(f'Boxplot of {col}')
plt.tight_layout()
plt.show()
# Out:
# After Removing Outliers

# %%
scatter_matrix(df_num, figsize=(10, 10))
plt.suptitle('Scatter Matrix of Numeric Features')
plt.tight_layout(rect=[0, 0.03, 1, 0.95])
plt.show()

# %%
corr = df_num.corr()
print("\nCorrelation matrix:\n", corr)
# Out:
# Correlation matrix:
#            Survived    Pclass       Age      Fare    Family
# Survived  1.000000 -0.338481 -0.064577  0.257307  0.016639
# Pclass   -0.338481  1.000000 -0.340279 -0.549500  0.065997
# Age      -0.064577 -0.340279  1.000000  0.096882 -0.245471
# Fare      0.257307 -0.549500  0.096882  1.000000  0.217138
# Family    0.016639  0.065997 -0.245471  0.217138  1.000000

# %%
plt.figure(figsize=(6, 5))
plt.imshow(corr, interpolation='nearest', aspect='auto')
plt.colorbar()
plt.xticks(range(len(corr)), corr.columns, rotation=45)
plt.yticks(range(len(corr)), corr.index)
plt.title('Correlation Heatmap')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Fare Distribution

# %%
plt.figure(figsize=(8, 4))
sns.histplot(df_num['Fare'], bins=40, kde=True)
plt.title('Fare Distribution')
plt.xlabel('Fare')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Survival rate by class

# %%
plt.figure(figsize=(6, 4))
sns.barplot(x='Pclass', y='Survived', data=df_num)
plt.title('Survival Rate by Passenger Class')
plt.ylabel('Survival Rate')
plt.show()

# %% [markdown]
# # Fare vs. Survival

# %%
plt.figure(figsize=(8, 4))
sns.boxplot(x='Survived', y='Fare', data=df_num)
plt.title('Fare vs. Survival')
plt.xlabel('Survived (0 = No, 1 = Yes)')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# # Age Distribution

# %%
plt.figure(figsize=(8, 4))
sns.histplot(df_num['Age'].dropna(), bins=30, kde=True)
plt.title('Age Distribution')
plt.xlabel('Age')
plt.show()

# %% [markdown]
# # Distribution of family size

# %%
df['FamilyType'] = df_num['Family'].apply(
    lambda x: 'Alone' if x == 0 else ('Small' if x <= 3 else 'Large')
)

# %%
plt.figure(figsize=(6, 4))
sns.countplot(x='Family', data=df_num)
plt.title('Family Type Distribution')
plt.xlabel('Family Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# # Survival Rate by Passenger Class

# %%
survival_by_class = df.groupby('Pclass')['Survived'].mean()
print("Survival rate by class:\n", survival_by_class)
# Out:
# Survival rate by class:
#  Pclass
# 1    0.563830
# 2    0.446667
# 3    0.250000
# Name: Survived, dtype: float64

# %%
plt.figure(figsize=(6, 4))
sns.barplot(x='Pclass', y='Survived', data=df)
plt.title('Survival Rate by Passenger Class')
plt.ylabel('Survival Rate')
plt.xlabel('Pclass')
plt.ylim(0, 1)
plt.show()

# %% [markdown]
# # Survival Rate for Children (Age < 16)

# %%
# Create 'IsChild' column
df['IsChild'] = df['Age'] < 16

survival_by_age_group = df.groupby('IsChild')['Survived'].mean()
print("Survival rate (children vs. adults):\n", survival_by_age_group)
# Out:
# Survival rate (children vs. adults):
#  IsChild
# False    0.31746
# True     0.80000
# Name: Survived, dtype: float64

# %%
plt.figure(figsize=(6, 4))
sns.barplot(x='IsChild', y='Survived', data=df)
plt.title('Survival Rate: Children vs. Adults')
plt.ylabel('Survival Rate')
plt.xticks([0, 1], ['Adult', 'Child'])
plt.ylim(0, 1)
plt.show()

# %%
# Already created 'Family' = SibSp + Parch
# Create 'FamilySizeGroup'
df['FamilySizeGroup'] = df['Family'].apply(
    lambda x: 'Large' if x >= 3 else ('Small' if x > 0 else 'Alone')
)

# Survival rate by family size group
survival_by_family = df.groupby('FamilySizeGroup')['Survived'].mean()
print("Survival rate by family size:\n", survival_by_family)
